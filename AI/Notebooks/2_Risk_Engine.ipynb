# %% [markdown]
# # <b>Risk Engine

# %% [markdown]
# ### Importing Libraries

# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report

# %% [markdown]
# ## Load Dataset

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
df = pd.read_csv('/content/drive/MyDrive/MIRA/Datasets/mira_10k_risk_scoring_dataset.csv')

df.head()
# Out:
#                            issue     category severity recurring    risk
# 0  Personal Protective Equipment       Safety     High        No  Medium
# 1                    Fire Safety  Mine Safety   Medium       Yes    High
# 2              Electrical Safety       Safety   Medium       Yes    High
# 3                    Fire Safety  Mine Safety     High        No    High
# 4                    Fire Safety  Mine Safety      Low        No     Low

# %%
X = df[
    [
        'issue',
        'category',
        'severity',
        'recurring'
    ]
]

y = df['risk']

# %% [markdown]
# ### One-Hot Encode

# %%
encoder = OneHotEncoder(
    handle_unknown='ignore',
    sparse_output=False
)

X_encoded = encoder.fit_transform(X)

print(X_encoded.shape)
# Out:
# (10000, 23)

# %%
risk_labels = {
    'Low': 0,
    'Medium': 1,
    'High': 2,
    'Critical': 3
}

y_encoded = y.map(risk_labels).values

# %% [markdown]
# ## Train-Test Split

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_encoded,
    y_encoded,
    test_size = 0.2,
    random_state = 42,
    stratify = y_encoded
)

# %% [markdown]
# ## Model

# %%
model = LogisticRegression(
    max_iter = 3000,
    multi_class = 'multinomial',
    random_state = 42
)

# %% [markdown]
# ### Training

# %%
model.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.13/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# LogisticRegression(max_iter=3000, multi_class='multinomial', random_state=42)

# %% [markdown]
# ### Prediction on Test data samples

# %%
y_pred = model.predict(X_test)

# %% [markdown]
# ### Checking Accuracy

# %%
accuracy = accuracy_score(y_test, y_pred)

print(f"Accuracy: {accuracy * 100:.2f}%")
# Out:
# Accuracy: 100.00%

# %% [markdown]
# ## Saving the model and One-Hot Encoder

# %%
import joblib

MODEL_PATH = '/content/drive/MyDrive/MIRA/models/mira-risk-classifier.pkl'
ENCODER_PATH = '/content/drive/MyDrive/MIRA/models/mira-risk-encoder.pkl'

joblib.dump(model, MODEL_PATH)
joblib.dump(encoder, ENCODER_PATH)

print("Risk model and encoder saved successfully.")
# Out:
# Risk model and encoder saved successfully.
